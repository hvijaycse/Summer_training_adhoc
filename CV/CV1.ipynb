# %%
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
import numpy as np

# %%
image1=cv2.imread('1.jpg')

# %%
image2=cv2.imread('2.jpg')

# %%
h,w,p=image1.shape

# %%
new=np.concatenate((image1[0:,0:int(w/2)],image2[0:,int(w/2):]),axis=1)

# %%
cv2_imshow(new)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300 at 0x7FAEBA233358>

# %%
image1[0:11,0:21]=image2[0:11,0:21]

# %%
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300 at 0x7FAEBA233710>
